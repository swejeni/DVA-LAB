# %% [markdown]
# ### Lab7. Data Visualization in Seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train_upvote_mini.csv")
df.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0

# %%
df.size
# Out:
# 108080

# %%
df.shape
# Out:
# (15440, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15440 entries, 0 to 15439
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          15440 non-null  int64
#  1   Tag         15440 non-null  object
#  2   Reputation  15440 non-null  float64
#  3   Answers     15440 non-null  float64
#  4   Username    15440 non-null  int64
#  5   Views       15440 non-null  float64
#  6   Upvotes     15440 non-null  float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 844.5+ KB

# %%
df.dtypes
# Out:
# ID              int64
# Tag            object
# Reputation    float64
# Answers       float64
# Username        int64
# Views         float64
# Upvotes       float64
# dtype: object

# %%
df['Tag'].unique()
# Out:
# array(['a', 'c', 'r', 'j', 'p', 's', 'h', 'o', 'i', 'x'], dtype=object)

# %%
plt.scatter(x=df['Views'],y=df['Upvotes'])

# %%
sns.relplot(data=df,x='Views',y='Upvotes')

# %%
sns.relplot(data=df,x='Views',y='Upvotes',hue='Tag')

# %%
sns.relplot(data=df,x='Views',y='Upvotes',hue='Answers')

# %%
sns.relplot(data=df,x='Views',y='Upvotes',size='Tag')

# %%
sns.relplot(data=df, x="Answers", y="Upvotes", kind='line')

# %%
sns.relplot(data=df, x="Reputation", y="Upvotes")

# %%
df1 = pd.read_csv('train_hr_mini.csv')
df1.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
df1.shape
# Out:
# (6397, 14)

# %%
sns.stripplot(data=df1, x="education", y="avg_training_score", jitter=True)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.stripplot(data=df1, x="education", y="avg_training_score", jitter=False)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.swarmplot(data=df1, x="education", y="avg_training_score")
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 74.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.swarmplot(data=df1, x="education", y="avg_training_score", hue ='gender')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 74.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.swarmplot(data=df1, x="education", y="avg_training_score", hue='is_promoted')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 74.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.boxplot(data=df1, x="education", y="avg_training_score")
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.boxplot(data=df1, x="education", y="avg_training_score", hue ='is_promoted')
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.violinplot(data=df1, x="education", y="avg_training_score", hue ='is_promoted')
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.violinplot(data=df1, x="education", y="avg_training_score", hue ='is_promoted',split=True)
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.barplot(data=df1, x="education", y="avg_training_score", hue ='is_promoted')
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.pointplot(data=df1, x="education", y="avg_training_score", hue ='is_promoted')
# Out:
# <AxesSubplot:xlabel='education', ylabel='avg_training_score'>

# %%
sns.catplot(data=df1, x="education", y="avg_training_score", hue ='is_promoted',kind='swarm')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 56.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 81.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.histplot(x='age', data=df1, kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(x='age', data=df1)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.jointplot(x='avg_training_score',y='age', data=df1 )

# %%
sns.jointplot(x='avg_training_score',y='age',kind='hex', data=df1 )

# %%
sns.kdeplot(x='age',y='avg_training_score', data=df1 )
# Out:
# <AxesSubplot:xlabel='age', ylabel='avg_training_score'>

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='age',y='avg_training_score', data=df1, kind='boxen', height=15, aspect=.5 )

# %%
sns.pairplot(df1)
